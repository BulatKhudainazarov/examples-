# %%
import random

a = random.randint(0, 10)
b = int(input("Введите число от 0 до 10: "))

running = True

while running:
    if a == b:
        print("Вы угадали!")

        a = random.randint(0, 10)
        b = int(input("Угадайте снова число от 0 до 10: "))
    elif b > a:
        print("Меньше")

        b = int(input("Введите число от 0 до 10: "))
    else:
        print("Больше")

        b = int(input("Введите число от 0 до 10: "))
print("Вы угадали!")
b = int(input("Введите число от 0 до 10: "))
# Out:
# Введите число от 0 до 10: 12
# Меньше
# Введите число от 0 до 10: 23
# Меньше
# Введите число от 0 до 10: 1
# Вы угадали!
# Угадайте снова число от 0 до 10: 2
# Вы угадали!
# Угадайте снова число от 0 до 10: 3
# Вы угадали!
# Угадайте снова число от 0 до 10: 1
# Больше
# Введите число от 0 до 10: 2
# Больше
# Введите число от 0 до 10: 3
# Больше
# Введите число от 0 до 10: 4
# Больше
# Введите число от 0 до 10: 4
# Больше
# Введите число от 0 до 10: 5
# Вы угадали!
# Угадайте снова число от 0 до 10: 6
# Больше
# Введите число от 0 до 10: 7
# Вы угадали!
# Угадайте снова число от 0 до 10: 8
# Меньше
# Введите число от 0 до 10: 9
# Меньше
# Введите число от 0 до 10: 1
# Больше
# Введите число от 0 до 10: 2
# Вы угадали!
# Угадайте снова число от 0 до 10: 3
# Меньше
# Введите число от 0 до 10: 4
# Меньше
# Введите число от 0 до 10: 5
# Меньше
# Введите число от 0 до 10: 674567
# Меньше
# Введите число от 0 до 10: 1
# Вы угадали!
# Угадайте снова число от 0 до 10: 2
# Больше
# Введите число от 0 до 10: 34
# Меньше
# Введите число от 0 до 10: 3
# Вы угадали!
